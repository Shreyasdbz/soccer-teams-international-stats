# %%
import csv
import pandas as pd
import matplotlib
import bar_chart_race as bcr
import helper_functions

# %% [markdown]
# STEP 1:
# * Import Raw Data

# %%
FILTER_YEAR_START = 1900
FILTER_YEAR_END = 2020

raw_data = []
unique_years = []
unique_teams = []

with open('data/results.csv') as results_file:
    reader = csv.reader(results_file)
    next(reader)
    for matchup in reader:
        # matchup[0] : date
        # matchup[1] : home team
        # matchup[2] : away team
        # matchup[3] : home score
        # matchup[4] : away score
        year = str(helper_functions.extract_date_to_year(matchup[0]))
        if int(year) < FILTER_YEAR_START or int(year) > FILTER_YEAR_END:
            continue
        raw_data.append(matchup)
        if year not in unique_years:
            unique_years.append(year)
        home_team = matchup[1]
        away_team = matchup[2]
        if home_team not in unique_teams:
            unique_teams.append(home_team)
        if away_team not in unique_teams:
            unique_teams.append(away_team)

unique_years = sorted(unique_years)
unique_teams = sorted(unique_teams)

# %% [markdown]
# Step 3:
# * Create and fill a dictionary with related year values

# %%
# Data dictionary format:
# data_dict = {
#   '1940' : { 'England': 4 , 'Wales': 1, ... },
#   '1950' : { 'England': 6 , 'Wales': 3, ... },
#   ...
#   }
data_dict = {}

# Create an empty dict of dicts to be populated later
for y in unique_years: 
    empty_teams_list = {}
    for team in unique_teams:
        empty_teams_list[team] = 0
    data_dict[y] = empty_teams_list

# test dataframe
# df = pd.DataFrame(data_dict)
# df_t = df.T
# print(df_t)

# %%
# Fill the dictionary by using the raw data
for match in raw_data:
    current_year = str(helper_functions.extract_date_to_year(match[0]))
    home_team = ''
    away_team = ''
    home_score = 0
    away_score = 0
    if (match[3]).upper() == 'NA' or (match[4]).upper() == 'NA' :
        continue
    home_team = match[1]
    away_team = match[2]
    home_score = int(match[3])
    away_score = int(match[4])
    # Home Team Win
    # print('{} : {} --- vs --- {} : {}'.format(home_team, home_score, away_team, away_score))
    if home_score > away_score:
        current_wins = int(data_dict[current_year][home_team])
        # print('For {} - adding to {}'.format(current_year, home_team))
        current_wins += 1
        data_dict[current_year][home_team] = current_wins        
    # Away Team Win
    elif home_score < away_score:
        current_wins = int(data_dict[current_year][away_team])
        # print('For {} - adding to {}'.format(current_year, away_team))
        current_wins += 1
        data_dict[current_year][away_team] = current_wins        
    # Draw
    elif home_score == away_score:
        # noOp
        pass
    else:
        print('ERROR: Match score unreadable')

# print(data_dict)
# test dataframe
# df = pd.DataFrame(data_dict)
# df_t = df.T
# print(df_t)

# %% [markdown]
# Step 4:
# * Ripple wins down the years

# %%
wins_temp = empty_teams_list
# print(wins_temp)
for year in data_dict:
    for team in data_dict[year]:
        data_dict[year][team] += int(wins_temp[team])
    wins_temp = data_dict[year]

# print(data_dict)

data_frame_inital = pd.DataFrame(data_dict)
data_frame_t = data_frame_inital.T
# print(df_t)

# %% [markdown]
# Step:
# * BCR

# %%
# bcr.bar_chart_race(
#     df=data_frame_t,
#     filename='teams_wins_race.mp4',
#     orientation='h',
#     sort='desc',
#     n_bars=7,
#     fixed_order=False,
#     fixed_max=True,
#     steps_per_period=10,
#     interpolate_period=False,
#     label_bars=True,
#     bar_size=.95,
#     period_label={'x': .99, 'y': .25, 'ha': 'right', 'va': 'center'},
#     period_fmt='',
#     period_summary_func=lambda v, r: {'x': .99, 'y': .18,
#                                     #   's': f'Total wins: {v.nlargest(6).sum():,.0f}',
#                                       's': '',
#                                       'ha': 'right', 'size': 8, 'family': 'Helvetica'},
#     perpendicular_bar_func='median',
#     period_length=500,
#     figsize=(5, 3),
#     dpi=256,
#     cmap='dark12',
#     title='Wins by international teams',
#     title_size='',
#     bar_label_size=7,
#     tick_label_size=7,
#     shared_fontdict={'family' : 'Helvetica', 'color' : '.1'},
#     scale='linear',
#     writer=None,
#     fig=None,
#     bar_kwargs={'alpha': .7},
#     filter_column_colors=True)

# %%
bcr.bar_chart_race(
    df=data_frame_t, 
    # filename='teams_wins_race.mp4',
    sort='desc', 
    steps_per_period=20, 
    figsize=(7, 4), 
    n_bars=7,
    title='Wins by international teams',
    filter_column_colors=True,
    dpi=512,
    scale='linear',
    bar_size=.85,
    # period_label={'x': .99, 'y': .25, 'ha': 'right', 'va': 'center'},
    bar_label_size=7,
    tick_label_size=7,
    )
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 127 () missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 128 (\x80) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 129 (\x81) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 130 (\x82) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 131 (\x83) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 132 (\x84) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 133 (\x85) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 134 (\x86) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 135 (\x87) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 136 (\x88) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 137 (\x89) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 138 (\x8a) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 139 (\x8b) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 140 (\x8c) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 141 (\x8d) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 142 (\x8e) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 143 (\x8f) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 144 (\x90) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 145 (\x91) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 146 (\x92) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 147 (\x93) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 148 (\x94) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 149 (\x95) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 150 (\x96) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 151 (\x97) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 152 (\x98) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 153 (\x99) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 154 (\x9a) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 155 (\x9b) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 156 (\x9c) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 157 (\x9d) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 158 (\x9e) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:284: UserWarning: Glyph 159 (\x9f) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
